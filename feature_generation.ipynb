# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Incorprate AOA

# %%
bert_label = pd.read_csv('train_data_bert_label.csv', header = 0)[['predicted_label']]
bert_label
# Out:
#         predicted_label
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 416763                0
# 416764                0
# 416765                0
# 416766                0
# 416767                0
#
# [416768 rows x 1 columns]

# %%
aoa_df = pd.read_csv('AOA_51715_words.csv', header = 0, index_col = 0)
aoa_df.head()
# Out:
#          Alternative.spelling   Freq_pm Dom_PoS_SUBTLEX  Nletters  Nphon  \
# Word
# a                           a  20415.27         Article         1      1
# aardvark             aardvark      0.41            Noun         8      7
# abacus                 abacus      0.24            Noun         6      6
# abacuses             abacuses      0.02            Noun         8      9
# abalone               abalone      0.51            Verb         7      7
#
#           Nsyll Lemma_highest_PoS  AoA_Kup  Perc_known  AoA_Kup_lem  \
# Word
# a             1                 a     2.89        1.00         2.89
# aardvark      2          aardvark     9.89        1.00         9.89
# abacus        3            abacus     8.69        0.65         8.69
# abacuses      4            abacus      NaN         NaN         8.69
# abalone       4           abalone    12.23        0.72        12.23
#
#           Perc_known_lem  AoA_Bird_lem  AoA_Bristol_lem  AoA_Cort_lem  \
# Word
# a                   1.00          3.16              NaN           NaN
# aardvark            1.00           NaN              NaN           NaN
# abacus              0.65           NaN              NaN           NaN
# abacuses            0.65           NaN              NaN           NaN
# abalone             0.72           NaN              NaN           NaN
#
#           AoA_Schock
# Word
# a                NaN
# aardvark         NaN
# abacus           NaN
# abacuses         NaN
# abalone          NaN

# %%
aoa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51715 entries, a to zygotes
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alternative.spelling  51714 non-null  object
#  1   Freq_pm               51046 non-null  float64
#  2   Dom_PoS_SUBTLEX       50963 non-null  object
#  3   Nletters              51715 non-null  int64
#  4   Nphon                 51715 non-null  int64
#  5   Nsyll                 51715 non-null  int64
#  6   Lemma_highest_PoS     51714 non-null  object
#  7   AoA_Kup               31105 non-null  float64
#  8   Perc_known            31124 non-null  float64
#  9   AoA_Kup_lem           51695 non-null  float64
#  10  Perc_known_lem        51715 non-null  float64
#  11  AoA_Bird_lem          5421 non-null   float64
#  12  AoA_Bristol_lem       8061 non-null   float64
#  13  AoA_Cort_lem          8045 non-null   float64
#  14  AoA_Schock            7056 non-null   float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 6.3+ MB

# %%
train_data = pd.read_csv('WikiLarge_Train.csv', header = 0)
train_data.head()
# Out:
#                                        original_text  label
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1

# %%
def text_processing(x):
    x = re.sub(r'[^\w\s]','', x)
    x = x.split(' ')
    x = [word.strip().lower() for word in x]
    return x

# %%
train_data.loc[:, 'processed_text'] = train_data['original_text'].apply(text_processing)

# %%
train_data.head()
# Out:
#                                        original_text  label  \
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1
#
#                                       processed_text
# 0  [there, is, manuscript, evidence, that, austen...
# 1  [in, a, remarkable, comparative, analysis, , m...
# 2  [before, persephone, was, released, to, hermes...
# 3  [cogeneration, plants, are, commonly, found, i...
# 4  [geneva, lrb, , , , , , , , rrb, is, the, seco...

# %%
np.max(aoa_df.loc[:, 'AoA_Kup_lem'])
# Out:
# 25.0

# %%
def calculate_average_aoa(x):
    aoa_value_list = []
    
    for word in x:
        if word:
            try:
                aoa_value = aoa_df.loc[word, 'AoA_Kup_lem']
                aoa_value_list.append(aoa_value)
            except:
                pass
    
    if aoa_value_list:
        mean_aoa = np.mean(aoa_value_list)
    else:
        mean_aoa = 0
        
    return mean_aoa

# %%
train_data.loc[:, 'average_AoA_Kup_lem'] = train_data['processed_text'].apply(calculate_average_aoa)

# %%
train_data.head()
# Out:
#                                        original_text  label  \
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1
#
#                                       processed_text  average_AoA_Kup_lem
# 0  [there, is, manuscript, evidence, that, austen...            10.441842
# 1  [in, a, remarkable, comparative, analysis, , m...            13.332857
# 2  [before, persephone, was, released, to, hermes...             7.664762
# 3  [cogeneration, plants, are, commonly, found, i...             9.592187
# 4  [geneva, lrb, , , , , , , , rrb, is, the, seco...            14.498214

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416768 entries, 0 to 416767
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   original_text        416768 non-null  object
#  1   label                416768 non-null  int64
#  2   processed_text       416768 non-null  object
#  3   average_AoA_Kup_lem  416471 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 12.7+ MB

# %% [markdown]
# ## Incorprate percentage of basic words

# %%
with open('dale_chall.txt') as file_obj:
    basic_word_list = file_obj.readlines()
    cleaned_basic_word_list = [word.lower().strip() for word in basic_word_list]

# %%
len(cleaned_basic_word_list)
# Out:
# 2950

# %%
def calculate_percentage_of_basic_words(x):
    basic_count = 0
    word_count = 0
    for word in x:
        if word: 
            word_count += 1
            if word in cleaned_basic_word_list:
                basic_count += 1
    try:
        percentage = basic_count / word_count
    except:
        percentage = 1
        
    return percentage

# %%
train_data.loc[:, 'percentage_of_basic_words'] = train_data['processed_text'].apply(calculate_percentage_of_basic_words)

# %%
train_data.head()
# Out:
#                                        original_text  label  \
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1
#
#                                       processed_text  average_AoA_Kup_lem  \
# 0  [there, is, manuscript, evidence, that, austen...            10.441842
# 1  [in, a, remarkable, comparative, analysis, , m...            13.332857
# 2  [before, persephone, was, released, to, hermes...             7.664762
# 3  [cogeneration, plants, are, commonly, found, i...             9.592187
# 4  [geneva, lrb, , , , , , , , rrb, is, the, seco...            14.498214
#
#    percentage_of_basic_words
# 0                   0.552632
# 1                   0.285714
# 2                   0.619048
# 3                   0.312500
# 4                   0.500000

# %% [markdown]
# ## Incorprate Concreteness

# %%
concreteness_df = pd.read_csv('Concreteness_ratings_Brysbaert_et_al_BRM.txt', sep = '\t', header = 0, index_col = 0)
concreteness_df
# Out:
#                  Bigram  Conc.M  Conc.SD  Unknown  Total  Percent_known  \
# Word
# roadsweeper           0    4.85     0.37        1     27           0.96
# traindriver           0    4.54     0.71        3     29           0.90
# tush                  0    4.45     1.01        3     25           0.88
# hairdress             0    3.93     1.28        0     29           1.00
# pharmaceutics         0    3.77     1.41        4     26           0.85
# ...                 ...     ...      ...      ...    ...            ...
# unenvied              0    1.21     0.62        1     30           0.97
# agnostically          0    1.20     0.50        2     27           0.93
# conceptualistic       0    1.18     0.50        4     26           0.85
# conventionalism       0    1.18     0.48        1     29           0.97
# essentialness         0    1.04     0.20        2     26           0.92
#
#                  SUBTLEX Dom_Pos
# Word
# roadsweeper            0       0
# traindriver            0       0
# tush                  66       0
# hairdress              1       0
# pharmaceutics          0       0
# ...                  ...     ...
# unenvied               0     NaN
# agnostically           0     NaN
# conceptualistic        0     NaN
# conventionalism        0     NaN
# essentialness          0     NaN
#
# [39954 rows x 8 columns]

# %%
concreteness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39954 entries, roadsweeper to essentialness
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Bigram         39954 non-null  int64
#  1   Conc.M         39954 non-null  float64
#  2   Conc.SD        39954 non-null  float64
#  3   Unknown        39954 non-null  int64
#  4   Total          39954 non-null  int64
#  5   Percent_known  39954 non-null  float64
#  6   SUBTLEX        39954 non-null  int64
#  7   Dom_Pos        28707 non-null  object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.7+ MB

# %%
def calculate_average_concrete_mean(x):
    aoa_value_list = []
    min_conc_value = np.min(concreteness_df.loc[:, 'Conc.M'])
    for word in x:
        if word:
            try:
                aoa_value = concreteness_df.loc[word, 'Conc.M']
                aoa_value_list.append(aoa_value)
            except:
                pass
    
    if aoa_value_list:
        mean_aoa = np.mean(aoa_value_list)
    else:
        mean_aoa = np.nan
        
    return mean_aoa

# %%
train_data.loc[:, 'average_concreteness'] = train_data['processed_text'].apply(calculate_average_concrete_mean)

# %%
train_data.head()
# Out:
#                                        original_text  label  \
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1
#
#                                       processed_text  average_AoA_Kup_lem  \
# 0  [there, is, manuscript, evidence, that, austen...            10.441842
# 1  [in, a, remarkable, comparative, analysis, , m...            13.332857
# 2  [before, persephone, was, released, to, hermes...             7.664762
# 3  [cogeneration, plants, are, commonly, found, i...             9.592187
# 4  [geneva, lrb, , , , , , , , rrb, is, the, seco...            14.498214
#
#    percentage_of_basic_words  average_concreteness
# 0                   0.552632              1.974211
# 1                   0.285714              1.655714
# 2                   0.619048              2.106667
# 3                   0.312500              2.324375
# 4                   0.500000              1.749643

# %%
np.min(concreteness_df.loc[:, 'Percent_known'])
# Out:
# 0.85

# %%
def calculate_percentage_known_mean(x):
    aoa_value_list = []
    min_known_value = np.min(concreteness_df.loc[:, 'Percent_known'])
    for word in x:
        if word:
            try:
                aoa_value = concreteness_df.loc[word, 'Percent_known']
                aoa_value_list.append(aoa_value)
            except:
                pass
    
    if aoa_value_list:
        mean_aoa = np.mean(aoa_value_list)
    else:
        mean_aoa = 1
        
    return mean_aoa

# %%
train_data.loc[:, 'average_percentage_known'] = train_data['processed_text'].apply(calculate_percentage_known_mean)

# %%
train_data.head()
# Out:
#                                        original_text  label  \
# 0  There is manuscript evidence that Austen conti...      1
# 1  In a remarkable comparative analysis , Mandaea...      1
# 2  Before Persephone was released to Hermes , who...      1
# 3  Cogeneration plants are commonly found in dist...      1
# 4  Geneva -LRB- , ; , ; , ; ; -RRB- is the second...      1
#
#                                       processed_text  average_AoA_Kup_lem  \
# 0  [there, is, manuscript, evidence, that, austen...            10.441842
# 1  [in, a, remarkable, comparative, analysis, , m...            13.332857
# 2  [before, persephone, was, released, to, hermes...             7.664762
# 3  [cogeneration, plants, are, commonly, found, i...             9.592187
# 4  [geneva, lrb, , , , , , , , rrb, is, the, seco...            14.498214
#
#    percentage_of_basic_words  average_concreteness  average_percentage_known
# 0                   0.552632              1.974211                  0.995926
# 1                   0.285714              1.655714                  0.994167
# 2                   0.619048              2.106667                  0.992647
# 3                   0.312500              2.324375                  0.993333
# 4                   0.500000              1.749643                  0.989333

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416768 entries, 0 to 416767
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   original_text              416768 non-null  object
#  1   label                      416768 non-null  int64
#  2   processed_text             416768 non-null  object
#  3   average_AoA_Kup_lem        416471 non-null  float64
#  4   percentage_of_basic_words  416479 non-null  float64
#  5   average_concreteness       416479 non-null  float64
#  6   average_percentage_known   404958 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 22.3+ MB

# %%
train_data.to_csv('train_data_with_feature_ver_2.csv', index = False)

# %%
def generate_features(train_data):
    
    train_data.loc[:, 'processed_text'] = train_data['original_text'].apply(text_processing)
    train_data.loc[:, 'text_length'] = train_data['processed_text'].apply(lambda x: len(x))
    train_data['text_length'] = pd.cut(train_data['text_length'], bins = [0, 10, 20, 30, 40, 100], labels = [0, 1, 2, 3, 4])
    train_data['text_length'] = train_data['text_length'].astype('int64')
    train_data.loc[:, 'average_AoA_Kup_lem'] = train_data['processed_text'].apply(calculate_average_aoa)
    train_data.loc[:, 'percentage_of_basic_words'] = train_data['processed_text'].apply(calculate_percentage_of_basic_words)
    train_data.loc[:, 'average_concreteness'] = train_data['processed_text'].apply(calculate_average_concrete_mean)
    train_data.loc[:, 'average_percentage_known'] = train_data['processed_text'].apply(calculate_percentage_known_mean)

    return train_data

# %%
train_data = pd.read_csv('WikiLarge_Test.csv', header = 0, index_col = 0)

# %%
train_data
# Out:
#        original_text  label
# id
# 0              -2011    NaN
# 1              -2011    NaN
# 2              -2000    NaN
# 3              -1997    NaN
# 4              1.636    NaN
# ...              ...    ...
# 119087        #NAME?    NaN
# 119088        #NAME?    NaN
# 119089        #NAME?    NaN
# 119090        #NAME?    NaN
# 119091        #NAME?    NaN
#
# [119092 rows x 2 columns]

# %%
train_data = generate_features(train_data)
train_data
# Out:
#        original_text  label processed_text  text_length  average_AoA_Kup_lem  \
# id
# 0              -2011    NaN         [2011]            0                 0.00
# 1              -2011    NaN         [2011]            0                 0.00
# 2              -2000    NaN         [2000]            0                 0.00
# 3              -1997    NaN         [1997]            0                 0.00
# 4              1.636    NaN         [1636]            0                 0.00
# ...              ...    ...            ...          ...                  ...
# 119087        #NAME?    NaN         [name]            0                 3.68
# 119088        #NAME?    NaN         [name]            0                 3.68
# 119089        #NAME?    NaN         [name]            0                 3.68
# 119090        #NAME?    NaN         [name]            0                 3.68
# 119091        #NAME?    NaN         [name]            0                 3.68
#
#         percentage_of_basic_words  average_concreteness  \
# id
# 0                             0.0                   NaN
# 1                             0.0                   NaN
# 2                             0.0                   NaN
# 3                             0.0                   NaN
# 4                             0.0                   NaN
# ...                           ...                   ...
# 119087                        1.0                   3.5
# 119088                        1.0                   3.5
# 119089                        1.0                   3.5
# 119090                        1.0                   3.5
# 119091                        1.0                   3.5
#
#         average_percentage_known
# id
# 0                           1.00
# 1                           1.00
# 2                           1.00
# 3                           1.00
# 4                           1.00
# ...                          ...
# 119087                      0.96
# 119088                      0.96
# 119089                      0.96
# 119090                      0.96
# 119091                      0.96
#
# [119092 rows x 8 columns]

# %%
train_data.to_csv("test_data_with_feature_ver_3.csv")
